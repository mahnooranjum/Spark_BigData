# %%
import pyspark

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('Basic').getOrCreate()
# Out:
# 21/11/24 13:11:51 WARN Utils: Your hostname, maq-VirtualBox resolves to a loopback address: 127.0.1.1; using 10.0.2.15 instead (on interface enp0s3)
# 21/11/24 13:11:51 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/home/maq/spark-3.2.0-bin-hadoop3.2/jars/spark-unsafe_2.12-3.2.0.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# ...

# %%
# %%time
df = spark.read.csv("/media/sf_Drive/f_11G.csv", header = False, inferSchema=False)
df.printSchema()
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- _c1: string (nullable = true)
#  |-- _c2: string (nullable = true)
#  |-- _c3: string (nullable = true)
#  |-- _c4: string (nullable = true)
#  |-- _c5: string (nullable = true)
#  |-- _c6: string (nullable = true)
#  |-- _c7: string (nullable = true)
#  |-- _c8: string (nullable = true)
#  |-- _c9: string (nullable = true)
#  |-- _c10: string (nullable = true)
#  |-- _c11: string (nullable = true)
#  |-- _c12: string (nullable = true)
#  |-- _c13: string (nullable = true)
#  |-- _c14: string (nullable = true)
#  |-- _c15: string (nullable = true)
#  |-- _c16: string (nullable = true)
#  |-- _c17: string (nullable = true)
#  |-- _c18: string (nullable = true)
#  |-- _c19: string (nullable = true)
#  |-- _c20: string (nullable = true)
#  |-- _c21: string (nullable = true)
#  |-- _c22: string (nullable = true)
#  |-- _c23: string (nullable = true)
#  |-- _c24: string (nullable = true)
#  |-- _c25: string (nullable = true)
# ...

# %%
# %%time
df.agg({'_c50': 'sum'}).show()
# Out:
# [Stage 10:=======================================================>(90 + 1) / 91]
# +--------------------+
# |           sum(_c50)|
# +--------------------+
# |4.422960814147602...|
# +--------------------+
#
# CPU times: user 96.1 ms, sys: 85.2 ms, total: 181 ms
# Wall time: 4min 5s

# %%
# %%time
df.describe().show()
# Out:
# 21/11/24 14:04:45 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# ...

# %%
df.agg({'_c50': 'count'}).show()

# %%
df.agg({'_c50': 'mean'}).show()
